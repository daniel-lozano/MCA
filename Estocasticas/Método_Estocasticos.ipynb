# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
T = 1.0
N = 1000
dt = T/N
#inicia arrays de floats 
dW = zeros(N)
W = zeros(N)

dW = sqrt(dt) * random.normal(size=4)
W = dW.cumsum()
print W,dW
#plot(W)
# Out:
# [ 0.00643876 -0.01747041 -0.03641681 -0.00504278] [ 0.00643876 -0.02390917 -0.0189464   0.03137403]

# %%
x=loadtxt(open("salida.dat","r"))
plot(x)
e1=zeros(1000)
e2=zeros(1000)
e3=zeros(1000)
e4=zeros(1000)
e5=zeros(1000)
E=zeros(1000)
for i in range(1000):
    e1[i]=x[i]
    e2[i]=x[i+1000]
    e3[i]=x[i+2000]
    e4[i]=x[i+3000]
    e2[i]=x[i+4000]
    E[i]=(e1[i]+e2[i]+e3[i]+e4[i]+e5[i])/5

# %%
plot(e1)
plot(e2)
plot(e3)
plot(e4)
plot(e5)
plot(E,lw=5)
