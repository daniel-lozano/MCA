# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a=loadtxt(open("osc_y.dat","r"))
b=loadtxt(open("osc_v.dat","r"))

# %%
print a[:,1]
# Out:
# [ 0.          0.00999983  0.01999917 ...,  1.414116    1.413972    1.413757  ]

# %%
plot(a[:,0],a[:,1])

# %%
plot(a[:,0],b[:,1])
